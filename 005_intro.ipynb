# %% [markdown]
# <div dir='rtl' align='right'>## مقدمة في البرمجة والتفكير النقدي وتدفق المنطق و بايثون## 1. مقدمة في البرمجةالبرمجة هي عملية تصميم وبناء برنامج حاسوبي قابل للتنفيذ لتحقيق مهمة محددة. تتم كتابة البرامج باستخدام لغات البرمجة التي توفر التعليمات التي يمكن للحواسيب فهمها وتنفيذها.### لماذا نتعلم البرمجة؟- **حل المشكلات:** تطوير القدرة على تقسيم المشكلات المعقدة إلى أجزاء أصغر وأكثر قابلية للإدارة.- **الأتمتة:** أتمتة المهام المتكررة، مما يجعل العمل أكثر كفاءة.- **فرص العمل:** مهارات البرمجة مطلوبة بشدة عبر مختلف الصناعات.### ما هي بايثون؟بايثون هي لغة برمجة عالية المستوى وعامة الغرض تُستخدم على نطاق واسع بسبب سهولة قراءتها وبساطتها. إنها لغة ممتازة للمبتدئين وتُستخدم في مجالات مثل تطوير الويب، علم البيانات، التعلم الآلي، وغيرها.</div>

# %%
# أول برنامج بايثون
print("مرحبًا بالعالم!")

# %% [markdown]
# <div dir='rtl' align='right'>## 2. التفكير النقدي في البرمجةالتفكير النقدي في البرمجة يتضمن تحليل وتقييم المشكلة بطريقة منطقية والتوصل إلى حل فعال. يشمل التشكيك في الافتراضات، تحديد العلاقات، وحل المشكلات بشكل منهجي.### العناصر الرئيسية للتفكير النقدي في البرمجة:- **الوضوح:** التأكد من أن المشكلة وفهمك لها واضحان.- **الدقة:** الانتباه إلى التفاصيل؛ الأخطاء الصغيرة يمكن أن تؤدي إلى أخطاء في البرنامج.- **التركيز:** التركيز على ما هو مهم لحل المشكلة.- **المنطق:** التأكد من أن تفكيرك متسق ويتدفق بشكل منطقي.**مثال:**</div>

# %%
# تمرين التفكير النقدي: حدد المشكلة في الكود التالي
x = 10
y = 0
print(x / y)  # ماذا يحدث هنا؟ لماذا؟

# %% [markdown]
# <div dir='rtl' align='right'>### الحل:هذا الكود سيؤدي إلى ظهور خطأ `ZeroDivisionError` لأن القسمة على الصفر غير مسموحة في الرياضيات. كمبرمج، عليك أن تتوقع مثل هذه المشكلات وتتعامل معها بشكل مناسب.</div>

# %%
# إصلاح الخطأ باستخدام التفكير النقدي
x = 10
y = 0
if y != 0:
    print(x / y)
else:
    print("لا يمكن القسمة على الصفر")

# %% [markdown]
# <div dir='rtl' align='right'>## 3. تدفق المنطقتدفق المنطق في البرمجة يشير إلى التسلسل الذي يتم تنفيذ الكود فيه. فهم هذا التدفق ضروري لكتابة برامج صحيحة وفعالة.### المفاهيم الأساسية:- **التنفيذ المتسلسل:** يتم تنفيذ الكود سطرًا بسطر.- **التنفيذ الشرطي:** يتم تنفيذ الكود بناءً على شروط (عبارات if-else).- **الحلقات:** يتكرر الكود حتى يتم تحقيق شرط معين (حلقات for وwhile).</div>

# %%
# مثال: التنفيذ المتسلسل
a = 5
b = 10
c = a + b
print(c)

# %%
# مثال: التنفيذ الشرطي
x = 10
if x > 5:
    print("x أكبر من 5")
else:
    print("x أقل من أو يساوي 5")

# %%
# مثال: حلقة for
for i in range(5):
    print(i)

# مثال: حلقة while
count = 0
while count < 5:
    print(count)
    count += 1

# %% [markdown]
# <div dir='rtl' align='right'>## 4. نهج حل المشكلات في البرمجة1. **فهم المشكلة:** ما هو المدخل؟ ما هو المخرج المتوقع؟ ما هي القيود؟2. **تخطيط الحل:** تقسيم المشكلة إلى خطوات.3. **كتابة الكود:** تنفيذ الحل خطوة بخطوة.4. **اختبار الحل:** تشغيل الكود بمدخلات مختلفة للتأكد من أنه يعمل بشكل صحيح.5. **تحسين:** تحسين الكود إذا لزم الأمر.### مثال على مشكلة:اكتب برنامجًا يحسب مجموع جميع الأرقام الزوجية من 1 إلى 100.</div>

# %%
# مجموع الأرقام الزوجية بين 1 و100
total = 0
for num in range(1, 101):
    if num % 2 == 0:
        total += num
print("مجموع الأرقام الزوجية من 1 إلى 100:", total)

# %% [markdown]
# <div dir='rtl' align='right'>## 5. مقدمة في هياكل البيانات في بايثونتوفر بايثون العديد من هياكل البيانات مثل القوائم، وال tuples، والمجموعات، والقواميس التي تساعد على تخزين البيانات وإدارتها بكفاءة.### القوائمالقائمة هي مجموعة من العناصر التي يمكن أن تكون من أنواع مختلفة. القوائم قابلة للتغيير، مما يعني أنه يمكنك تعديلها.</div>

# %%
# مثال على قائمة
my_list = [1, 2, 3, 4, 5]
print(my_list)
my_list.append(6)  # إضافة عنصر إلى القائمة
print(my_list)

# %% [markdown]
# <div dir='rtl' align='right'>### القواميستخزن القواميس أزواج القيمة المفتاحية وتكون مفيدة لربط البيانات ذات الصلة.</div>

# %%
# مثال على القاموس
person = {
    "name": "أليس",
    "age": 25,
    "city": "نيويورك"
}
print(person["name"])  # الوصول إلى قيمة باستخدام المفتاح

# %% [markdown]
# <div dir='rtl' align='right'>## 6. الخلاصةفي هذا الدفتر التفاعلي، قدمنا أساسيات البرمجة والتفكير النقدي وتدفق المنطق و بايثون. هذه هي المهارات الأساسية التي ستساعدك في رحلتك البرمجية. مع الممارسة، ستطور قدرات أقوى لحل المشكلات وتصبح متمكنًا في البرمجة باستخدام بايثون.### الخطوات التالية:- مارس حل المشكلات الأكثر تعقيدًا.- استكشف مكتبات بايثون مثل NumPy وpandas وmatplotlib لتحليل البيانات.- ابدأ في العمل على مشاريع صغيرة لتطبيق معرفتك في سيناريوهات العالم الحقيقي.</div>
