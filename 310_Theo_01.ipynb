# %% [markdown]
# # Definitions
#
# Python<br><br>
# Programming<br><br>
# Scope<br><br>
# loop<br><br>
# condition<br><br>
# function<br><br>
# type<br><br>
# variable<br><br>
# assignment<br><br>
# logical operation<br><br>
# arithmetic operation<br><br>
# incrementation<br><br>
# decrementation<br><br>
# initialization<br><br>

# %% [markdown]
# # Why Python?
